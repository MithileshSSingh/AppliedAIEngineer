# %% [markdown]
# # Topic Name
#
# **Module:** X — Module Name
# **Week:** Y
# **Date:** YYYY-MM-DD
#
# ## Learning Objectives
# - Objective 1
# - Objective 2
# - Objective 3

# %% [markdown]
# ## 1. Concept Overview
#
# Brief explanation of the concept in your own words.

# %%
# Setup
import sys
sys.path.insert(0, '../..')

from shared.viz_utils import setup_style
setup_style()

# %% [markdown]
# ## 2. Code Examples
#
# Hands-on code demonstrating the concept.

# %%
# Your code here

# %% [markdown]
# ## 3. Practice Exercises
#
# Small exercises to solidify understanding.

# %%
# Exercise 1

# %% [markdown]
# ## 4. Key Takeaways
#
# - Takeaway 1
# - Takeaway 2
# - Takeaway 3

# %% [markdown]
# ## Resources
# - [Resource 1](url)
# - [Resource 2](url)
