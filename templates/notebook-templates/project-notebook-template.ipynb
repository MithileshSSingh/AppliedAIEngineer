# %% [markdown]
# # Project Name
#
# **Module:** X — Module Name
# **Week:** Y
# **Date:** YYYY-MM-DD
#
# ## Problem Statement
# What problem are we solving and why?

# %%
# Setup
import sys
sys.path.insert(0, '../../..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from shared.viz_utils import setup_style
from shared.data_utils import load_csv, describe_df
setup_style()

# %% [markdown]
# ## 1. Data Loading & Exploration

# %%
# Load data
# df = load_csv('data/dataset.csv')
# describe_df(df)

# %% [markdown]
# ## 2. Data Cleaning & Feature Engineering

# %%
# Your code here

# %% [markdown]
# ## 3. Analysis / Modeling

# %%
# Your code here

# %% [markdown]
# ## 4. Results & Visualization

# %%
# Your code here

# %% [markdown]
# ## 5. Conclusions
#
# - Finding 1
# - Finding 2
#
# ### What I Learned
# -
#
# ### What I'd Do Differently
# -
