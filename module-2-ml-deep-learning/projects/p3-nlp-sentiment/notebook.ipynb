# %% [markdown]
# # P3: NLP Sentiment Analysis
#
# **Module:** 2 — ML & Deep Learning
# **Week:** 8
#
# ## Problem Statement
# Build and compare sentiment analysis systems using classical ML and modern transformers.
#
# ## Metrics
# - Accuracy, F1-score (macro)
# - Per-class precision and recall
# - Inference speed

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# Optional: HuggingFace (install with: pip install transformers)
# from transformers import pipeline as hf_pipeline

sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ---
# ## 1. Load & Explore Data

# %%
from src.generate_data import generate_reviews

df = generate_reviews()
print(f"Shape: {df.shape}")
print(f"\nSentiment distribution:")
print(df['sentiment'].value_counts())
df.head()

# %%
# TODO: Explore the data
# - Distribution of review lengths by sentiment
# - Word cloud or top words per sentiment
# - Sample reviews from each sentiment class

# %% [markdown]
# ---
# ## 2. Text Preprocessing

# %%
# TODO: Clean the text
# - Lowercase all reviews
# - Remove excessive punctuation
# - Split into X (reviews) and y (sentiment labels)
# - Train/test split (80/20, stratified)

# %% [markdown]
# ---
# ## 3. Classical ML Baselines

# %%
# TODO: Build and compare 3 pipelines:
# 1. TfidfVectorizer + LogisticRegression
# 2. TfidfVectorizer + MultinomialNB (from sklearn.naive_bayes)
# 3. TfidfVectorizer + LinearSVC (from sklearn.svm)
#
# For each: fit, predict, print classification_report
# Store results for comparison

# %%
# TODO: For your best classical model:
# - Show the most positive and most negative words (highest/lowest coefficients)
# - Plot top 15 words for each sentiment class

# %% [markdown]
# ---
# ## 4. Pretrained Transformer

# %%
# TODO: Use HuggingFace sentiment pipeline
# from transformers import pipeline
# sentiment_pipe = pipeline("sentiment-analysis")
#
# Note: Default pipeline is binary (POSITIVE/NEGATIVE)
# You'll need to map neutral reviews or use a 3-class model
#
# Try: "nlptown/bert-base-multilingual-uncased-sentiment" for 1-5 star ratings
# Map: 1-2 stars -> negative, 3 -> neutral, 4-5 -> positive
#
# Evaluate on test set (may be slow -- use first 500 samples)

# %% [markdown]
# ---
# ## 5. Compare All Approaches

# %%
# TODO: Create comparison table and visualization
# - Accuracy, Macro F1, and inference time for each model
# - Bar chart comparison
# - Where do models agree? Where do they disagree?

# %% [markdown]
# ---
# ## 6. Error Analysis

# %%
# TODO: Find misclassified reviews
# - Which sentiment is hardest to classify?
# - Show examples where classical ML and transformer disagree
# - Are there patterns in errors? (length, sarcasm, mixed sentiment)

# %% [markdown]
# ---
# ## 7. Fine-tune DistilBERT (Stretch Goal)
#
# If you want to push further, fine-tune a small transformer on your dataset.

# %%
# STRETCH GOAL: Fine-tune DistilBERT
# from transformers import AutoModelForSequenceClassification, AutoTokenizer, Trainer, TrainingArguments
# from datasets import Dataset
#
# This requires the 'datasets' library: pip install datasets
# Follow the HuggingFace fine-tuning tutorial

# %% [markdown]
# ---
# ## Key Findings
#
# TODO:
# 1. Best model:
# 2. Classical vs Transformer tradeoff:
# 3. Hardest sentiment to classify:
# 4. Most surprising finding:
#
# ## What I Learned
# -
#
# ## What I'd Do Differently
# -
