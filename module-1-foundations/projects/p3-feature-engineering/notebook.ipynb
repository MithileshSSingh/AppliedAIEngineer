# %% [markdown]
# # P3: Feature Engineering Competition
#
# **Module:** 1 — Foundations & Data Engineering
# **Week:** 3
#
# **Competition:** [Fill in: House Prices / Spaceship Titanic]
# **Constraint:** Simple model only — all improvement from features!
#
# ## Approach
# Iteratively add feature groups, measure CV improvement, submit best to Kaggle.

# %%
import sys
sys.path.insert(0, '../../..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# Pick ONE:
# from sklearn.linear_model import LinearRegression as Model   # For House Prices
# from sklearn.ensemble import RandomForestRegressor as Model   # For House Prices
# from sklearn.linear_model import LogisticRegression as Model  # For Spaceship Titanic
# from sklearn.ensemble import RandomForestClassifier as Model  # For Spaceship Titanic

from shared.viz_utils import setup_style
setup_style()

# %% [markdown]
# ---
# ## 1. Load Data & Quick EDA

# %%
# TODO: Load the training and test data
# train = pd.read_csv('data/train.csv')
# test = pd.read_csv('data/test.csv')
# print(f"Train: {train.shape}, Test: {test.shape}")

# %%
# TODO: Quick EDA
# - Target distribution
# - Missing values per column
# - Data types overview

# %% [markdown]
# ---
# ## 2. Experiment Tracker

# %%
experiments = []

def log_experiment(name, score, n_features, notes=''):
    experiments.append({
        'name': name, 'cv_score': score, 
        'n_features': n_features, 'notes': notes
    })
    print(f"{'='*60}")
    print(f"  {name}")
    print(f"  Score: {score:.5f} | Features: {n_features}")
    print(f"  Notes: {notes}")
    print(f"{'='*60}")

# %% [markdown]
# ---
# ## 3. Baseline (Minimal Preprocessing)

# %%
# TODO: Build a minimal baseline
# - Use only numeric columns
# - Simple imputation (median)
# - StandardScaler
# - Evaluate with cross_val_score

# %% [markdown]
# ---
# ## 4. Feature Engineering Rounds
#
# ### Round 1: Better Missing Value Handling

# %%
# TODO

# %% [markdown]
# ### Round 2: Log Transforms for Skewed Features

# %%
# TODO

# %% [markdown]
# ### Round 3: Interaction & Domain Features

# %%
# TODO

# %% [markdown]
# ### Round 4: Categorical Encoding

# %%
# TODO

# %% [markdown]
# ### Round 5: Your Creative Features

# %%
# TODO: At least 3 features unique to your analysis

# %% [markdown]
# ---
# ## 5. Final Pipeline & Submission

# %%
# TODO: Build final pipeline with best features
# Generate predictions on test set
# Create submission CSV

# %% [markdown]
# ---
# ## 6. Results & Experiments Log

# %%
# exp_df = pd.DataFrame(experiments)
# print(exp_df.to_string(index=False))
# 
# fig, ax = plt.subplots(figsize=(10, 5))
# ax.plot(exp_df['name'], exp_df['cv_score'], 'bo-')
# ax.set_title('CV Score Progression')
# ax.set_ylabel('Score')
# plt.xticks(rotation=45, ha='right')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ---
# ## 7. Top 5 Features That Improved My Score
#
# 1. **Feature name:** — Description, why it helped
# 2. **Feature name:** — Description, why it helped
# 3. **Feature name:** — Description, why it helped
# 4. **Feature name:** — Description, why it helped
# 5. **Feature name:** — Description, why it helped
#
# ## What I Learned
# -
#
# ## Kaggle Score
# - Baseline:
# - Final:
# - Improvement:
